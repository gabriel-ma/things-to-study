# %%
# %matplotlib inline
import pandas as pd
import pydataset
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pydataset.data('titanic')

# %%
titanic['class'].value_counts().plot(kind='bar')

# %%
titanic.groupby('survived')['class'].value_counts().plot(kind='bar')

# %%
estados = pd.read_csv('populacao_brasil.csv')

# %%
estados.head()
# Out:
#   estado     total
# 0     SP  44846530
# 1     MG  21024678
# 2     RJ  16690709
# 3     BA  15276566
# 4     RS  11286500

# %%
estados['total'].plot(kind='hist')

# %%
fig, ax = plt.subplots()
plt.hist(estados['total'],  bins=15, orientation='horizontal')
ax.ticklabel_format(style='plain')
plt.show()

# %%
estados['porcentagem'] = estados['total'] / estados['total'].sum()

# %%
#gráfico de pizza
plt.pie(estados['porcentagem'], labels=estados['estado'])
# Out:
# ([<matplotlib.patches.Wedge at 0x11080b610>,
#   <matplotlib.patches.Wedge at 0x1109eb9d0>,
#   <matplotlib.patches.Wedge at 0x1109ebed0>,
#   <matplotlib.patches.Wedge at 0x1109f7490>,
#   <matplotlib.patches.Wedge at 0x1109f7a10>,
#   <matplotlib.patches.Wedge at 0x1109f7f90>,
#   <matplotlib.patches.Wedge at 0x110a01550>,
#   <matplotlib.patches.Wedge at 0x110a01ad0>,
#   <matplotlib.patches.Wedge at 0x110a0b0d0>,
#   <matplotlib.patches.Wedge at 0x110a0b650>,
#   <matplotlib.patches.Wedge at 0x110a0bbd0>,
#   <matplotlib.patches.Wedge at 0x110a16190>,
#   <matplotlib.patches.Wedge at 0x110a16710>,
#   <matplotlib.patches.Wedge at 0x110a16c90>,
#   <matplotlib.patches.Wedge at 0x110a22250>,
#   <matplotlib.patches.Wedge at 0x110a227d0>,
#   <matplotlib.patches.Wedge at 0x110a22d50>,
#   <matplotlib.patches.Wedge at 0x110a2d310>,
#   <matplotlib.patches.Wedge at 0x110a2d890>,
#   <matplotlib.patches.Wedge at 0x110a2de10>,
#   <matplotlib.patches.Wedge at 0x1109604d0>,
#   <matplotlib.patches.Wedge at 0x110a38950>,
#   <matplotlib.patches.Wedge at 0x110a38ed0>,
#   <matplotlib.patches.Wedge at 0x110a43490>,
#   <matplotlib.patches.Wedge at 0x110a43a10>,
#   <matplotlib.patches.Wedge at 0x110a43f90>,
#   <matplotlib.patches.Wedge at 0x110a4d550>],
#  [Text(0.853223,0.694269,'SP'),
#   Text(-0.126771,1.09267,'MG'),
#   Text(-0.700132,0.848419,'RJ'),
#   Text(-1.01573,0.422257,'BA'),
#   Text(-1.09994,-0.0116462,'RS'),
#   Text(-1.0319,-0.38103,'PR'),
#   Text(-0.863377,-0.681601,'PE'),
#   Text(-0.641291,-0.893725,'CE'),
#   Text(-0.387114,-1.02963,'PA'),
#   Text(-0.1401,-1.09104,'MA'),
#   Text(0.0916943,-1.09617,'SC'),
#   Text(0.315274,-1.05385,'GO'),
#   Text(0.482044,-0.988754,'AM'),
#   Text(0.598662,-0.922824,'PB'),
#   Text(0.706041,-0.843508,'ES'),
#   Text(0.796992,-0.758158,'RN'),
#   Text(0.871449,-0.67125,'AL'),
#   Text(0.934982,-0.57949,'MT'),
#   Text(0.98781,-0.483976,'PI'),
#   Text(1.02898,-0.388845,'DF'),
#   Text(1.05864,-0.298814,'MS'),
#   Text(1.07813,-0.218259,'SE'),
#   Text(1.08954,-0.151332,'RO'),
#   Text(1.09578,-0.0962159,'TO'),
#   Text(1.09852,-0.0570999,'AC'),
#   Text(1.09958,-0.0303329,'AP'),
#   Text(1.09997,-0.00861513,'RR')])
